# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# pwd
# Out:
# /content/drive/MyDrive/adv-robustness-resnet-vit

# %%
# %%bash
# cd /content/drive/MyDrive
#
# # remove old folder if exists (safe reset)
# rm -rf adv-robustness-resnet-vit
#
# # unzip fresh
# unzip adv-robustness-resnet-vit.zip
#
# # enter project
# cd adv-robustness-resnet-vit
#
# ls
# Out:
# Archive:  adv-robustness-resnet-vit.zip
#    creating: adv-robustness-resnet-vit/
#   inflating: adv-robustness-resnet-vit/requirements.txt
#    creating: adv-robustness-resnet-vit/configs/
#   inflating: adv-robustness-resnet-vit/configs/vit_pgd_at.yaml
#   inflating: adv-robustness-resnet-vit/configs/resnet_pgd_at.yaml
#   inflating: adv-robustness-resnet-vit/configs/resnet_trades.yaml
#   inflating: adv-robustness-resnet-vit/configs/resnet_clean.yaml
#   inflating: adv-robustness-resnet-vit/configs/vit_trades.yaml
#   inflating: adv-robustness-resnet-vit/configs/vit_clean.yaml
#    creating: adv-robustness-resnet-vit/scripts/
#   inflating: adv-robustness-resnet-vit/scripts/train.py
#   inflating: adv-robustness-resnet-vit/scripts/eval_and_plot.py
#    creating: adv-robustness-resnet-vit/data/
#    creating: adv-robustness-resnet-vit/data/cifar-10-batches-py/
#   inflating: adv-robustness-resnet-vit/data/cifar-10-batches-py/data_batch_1
# ...

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# pip install -r requirements.txt

# %%
# configs/resnet_clean.yaml
epochs: 20

# %%
# configs/vit_clean.yaml
epochs: 20

# %%
# configs/resnet_pgd_at.yaml
epochs: 10

# %%
# configs/resnet_trades.yaml
epochs: 10

# %%
# configs/vit_pgd_at.yaml
epochs: 5

# %%
# configs/vit_trades.yaml
epochs: 5

# %%
# %cd /content/drive/MyDrive/adv-robustness-resnet-vit
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/adv-robustness-resnet-vit
# /content/drive/MyDrive/adv-robustness-resnet-vit
# configs  data  outputs	requirements.txt  scripts  src

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
#
# # Clean (20)
# sed -i 's/^epochs: .*/epochs: 20/' configs/resnet_clean.yaml
# sed -i 's/^epochs: .*/epochs: 20/' configs/vit_clean.yaml
#
# # ResNet PGD/TRADES (10)
# sed -i 's/^epochs: .*/epochs: 10/' configs/resnet_pgd_at.yaml
# sed -i 's/^epochs: .*/epochs: 10/' configs/resnet_trades.yaml
#
# # ViT PGD/TRADES (5)  (your screenshot shows you want 5)
# sed -i 's/^epochs: .*/epochs: 5/' configs/vit_pgd_at.yaml
# sed -i 's/^epochs: .*/epochs: 5/' configs/vit_trades.yaml
#
# # show proof
# grep -n "epochs" configs/*.yaml
# Out:
# configs/resnet_clean.yaml:6:epochs: 20
# configs/resnet_pgd_at.yaml:6:epochs: 10
# configs/resnet_trades.yaml:6:epochs: 10
# configs/vit_clean.yaml:6:epochs: 20
# configs/vit_pgd_at.yaml:6:epochs: 5
# configs/vit_trades.yaml:6:epochs: 5

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/resnet_clean.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'clean', 'model': 'resnet18', 'image_size': 32, 'batch_size': 128, 'epochs': 20, 'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0.0005, 'optimizer': 'sgd', 'ckpt_path': 'outputs/checkpoints/resnet18_clean.pt'}
# Running Clean Training
# [CLEAN] Epoch 01/20 | Test Clean: 0.4413 | LR: 0.099384
#   ✓ Saved checkpoint: outputs/checkpoints/resnet18_clean.pt
# [CLEAN] Epoch 02/20 | Test Clean: 0.5235 | LR: 0.097553
#   ✓ Saved checkpoint: outputs/checkpoints/resnet18_clean.pt
# [CLEAN] Epoch 03/20 | Test Clean: 0.5756 | LR: 0.094550
#   ✓ Saved checkpoint: outputs/checkpoints/resnet18_clean.pt
# [CLEAN] Epoch 04/20 | Test Clean: 0.6191 | LR: 0.090451
#   ✓ Saved checkpoint: outputs/checkpoints/resnet18_clean.pt
# [CLEAN] Epoch 05/20 | Test Clean: 0.6110 | LR: 0.085355
# [CLEAN] Epoch 06/20 | Test Clean: 0.6818 | LR: 0.079389
#   ✓ Saved checkpoint: outputs/checkpoints/resnet18_clean.pt
# [CLEAN] Epoch 07/20 | Test Clean: 0.7156 | LR: 0.072700
# ...

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/vit_clean.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'clean', 'model': 'vit', 'image_size': 224, 'batch_size': 32, 'epochs': 20, 'lr': 0.0003, 'weight_decay': 0.05, 'optimizer': 'adamw', 'pretrained': True, 'ckpt_path': 'outputs/checkpoints/vit_clean.pt'}
# model.safetensors: 100% 346M/346M [00:01<00:00, 189MB/s]
# Running Clean Training
# [CLEAN] Epoch 01/20 | Test Clean: 0.5365 | LR: 0.000298
#   ✓ Saved checkpoint: outputs/checkpoints/vit_clean.pt
# [CLEAN] Epoch 02/20 | Test Clean: 0.6119 | LR: 0.000293
#   ✓ Saved checkpoint: outputs/checkpoints/vit_clean.pt
# [CLEAN] Epoch 03/20 | Test Clean: 0.6624 | LR: 0.000284
#   ✓ Saved checkpoint: outputs/checkpoints/vit_clean.pt
# [CLEAN] Epoch 04/20 | Test Clean: 0.6882 | LR: 0.000271
#   ✓ Saved checkpoint: outputs/checkpoints/vit_clean.pt
# [CLEAN] Epoch 05/20 | Test Clean: 0.7197 | LR: 0.000256
#   ✓ Saved checkpoint: outputs/checkpoints/vit_clean.pt
# [CLEAN] Epoch 06/20 | Test Clean: 0.7180 | LR: 0.000238
# ...

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/resnet_pgd_at.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'pgd_at', 'model': 'resnet18', 'image_size': 32, 'batch_size': 128, 'epochs': 10, 'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0.0005, 'optimizer': 'sgd', 'eps': 0.03137255, 'alpha': 0.00784314, 'pgd_steps': 10, 'ckpt_path': 'outputs/checkpoints/resnet18_pgd_at.pt'}
# Running PGD Adversarial Training (PGD-AT)
# [PGD-AT] Epoch 01/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.097553
#   ✓ Saved robust checkpoint: outputs/checkpoints/resnet18_pgd_at.pt
# [PGD-AT] Epoch 02/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.090451
# [PGD-AT] Epoch 03/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.079389
# [PGD-AT] Epoch 04/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.065451
# [PGD-AT] Epoch 05/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.050000
# [PGD-AT] Epoch 06/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.034549
# [PGD-AT] Epoch 07/10 | Test Clean: 0.1000 | Test PGD: 0.1000 | LR: 0.020611
# ...

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/vit_pgd_at.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'pgd_at', 'model': 'vit', 'image_size': 224, 'batch_size': 32, 'epochs': 5, 'lr': 0.0003, 'weight_decay': 0.05, 'optimizer': 'adamw', 'pretrained': True, 'eps': 0.03137255, 'alpha': 0.00784314, 'pgd_steps': 10, 'ckpt_path': 'outputs/checkpoints/vit_pgd_at.pt'}
# Running PGD Adversarial Training (PGD-AT)
# [PGD-AT] Epoch 01/5 | Test Clean: 0.2963 | Test PGD: 0.2306 | LR: 0.000271
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_pgd_at.pt
# [PGD-AT] Epoch 02/5 | Test Clean: 0.3513 | Test PGD: 0.2563 | LR: 0.000196
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_pgd_at.pt
# [PGD-AT] Epoch 03/5 | Test Clean: 0.3587 | Test PGD: 0.2605 | LR: 0.000104
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_pgd_at.pt
# [PGD-AT] Epoch 04/5 | Test Clean: 0.4116 | Test PGD: 0.2935 | LR: 0.000029
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_pgd_at.pt
# [PGD-AT] Epoch 05/5 | Test Clean: 0.4436 | Test PGD: 0.3085 | LR: 0.000000
# ...

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/resnet_trades.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'trades', 'model': 'resnet18', 'image_size': 32, 'batch_size': 128, 'epochs': 10, 'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0.0005, 'optimizer': 'sgd', 'eps': 0.03137255, 'alpha': 0.00784314, 'trades_steps': 10, 'beta': 6.0, 'ckpt_path': 'outputs/checkpoints/resnet18_trades.pt'}
# Running TRADES Training
# [TRADES] Epoch 01/10 | Loss: 2.1778 | Test Clean: 0.2887 | Test PGD: 0.2106 | LR: 0.097553
#   ✓ Saved robust checkpoint: outputs/checkpoints/resnet18_trades.pt
# [TRADES] Epoch 02/10 | Loss: 2.0695 | Test Clean: 0.3118 | Test PGD: 0.2017 | LR: 0.090451
# [TRADES] Epoch 03/10 | Loss: 2.0313 | Test Clean: 0.3679 | Test PGD: 0.2167 | LR: 0.079389
#   ✓ Saved robust checkpoint: outputs/checkpoints/resnet18_trades.pt
# [TRADES] Epoch 04/10 | Loss: 2.1222 | Test Clean: 0.2773 | Test PGD: 0.1751 | LR: 0.065451
# [TRADES] Epoch 05/10 | Loss: 2.1512 | Test Clean: 0.3344 | Test PGD: 0.1981 | LR: 0.050000
# ...

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/vit_trades.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'trades', 'model': 'vit', 'image_size': 224, 'batch_size': 32, 'epochs': 5, 'lr': 0.0003, 'weight_decay': 0.05, 'optimizer': 'adamw', 'pretrained': True, 'eps': 0.03137255, 'alpha': 0.00784314, 'trades_steps': 10, 'beta': 6.0, 'ckpt_path': 'outputs/checkpoints/vit_trades.pt'}
# Running TRADES Training
# [TRADES] Epoch 01/5 | Loss: 2.2084 | Test Clean: 0.3499 | Test PGD: 0.1865 | LR: 0.000271
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_trades.pt
# [TRADES] Epoch 02/5 | Loss: 2.0458 | Test Clean: 0.3643 | Test PGD: 0.2202 | LR: 0.000196
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_trades.pt
# [TRADES] Epoch 03/5 | Loss: 1.9963 | Test Clean: 0.4039 | Test PGD: 0.2208 | LR: 0.000104
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_trades.pt
# [TRADES] Epoch 04/5 | Loss: 1.9384 | Test Clean: 0.4489 | Test PGD: 0.2246 | LR: 0.000029
#   ✓ Saved robust checkpoint: outputs/checkpoints/vit_trades.pt
# ...

# %%
# !ls /content/drive/MyDrive/adv-robustness-resnet-vit/outputs/checkpoints
# !ls /content/drive/MyDrive/adv-robustness-resnet-vit/outputs/results_csv
# Out:
# resnet18_clean.pt   resnet18_trades.pt	vit_pgd_at.pt
# resnet18_pgd_at.pt  vit_clean.pt	vit_trades.pt

# %%
# !ls /content/drive/MyDrive/adv-robustness-resnet-vit/outputs/checkpoints
# Out:
# resnet18_clean.pt   resnet18_trades.pt	vit_pgd_at.pt
# resnet18_pgd_at.pt  vit_clean.pt	vit_trades.pt

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/eval_and_plot.py
# Out:
# usage: eval_and_plot.py [-h] --configs CONFIGS [CONFIGS ...]
#                         [--out_dir OUT_DIR]
# eval_and_plot.py: error: the following arguments are required: --configs

# %%
# !ls /content/drive/MyDrive/adv-robustness-resnet-vit/outputs/results_csv
# !ls /content/drive/MyDrive/adv-robustness-resnet-vit/outputs/plots
# Out:
# ls: cannot access '/content/drive/MyDrive/adv-robustness-resnet-vit/outputs/plots': No such file or directory

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
#
# PYTHONPATH=. python scripts/eval_and_plot.py \
#   --configs \
#     configs/resnet_clean.yaml \
#     configs/resnet_pgd_at.yaml \
#     configs/resnet_trades.yaml \
#     configs/vit_clean.yaml \
#     configs/vit_pgd_at.yaml \
#     configs/vit_trades.yaml
# Out:
# Using device: cuda
#
# Evaluating: configs/resnet_clean.yaml
#   ckpt: outputs/checkpoints/resnet18_clean.pt
#   Clean: 84.24% | FGSM: 6.32% | PGD: 0.22%
#
# Evaluating: configs/resnet_pgd_at.yaml
#   ckpt: outputs/checkpoints/resnet18_pgd_at.pt
#   Clean: 10.00% | FGSM: 10.00% | PGD: 10.00%
#
# Evaluating: configs/resnet_trades.yaml
#   ckpt: outputs/checkpoints/resnet18_trades.pt
#   Clean: 40.89% | FGSM: 24.22% | PGD: 23.73%
#
# Evaluating: configs/vit_clean.yaml
#   ckpt: outputs/checkpoints/vit_clean.pt
#   Clean: 86.19% | FGSM: 1.44% | PGD: 0.00%
#
# Evaluating: configs/vit_pgd_at.yaml
#   ckpt: outputs/checkpoints/vit_pgd_at.pt
#   Clean: 44.36% | FGSM: 31.08% | PGD: 30.87%
#
# Evaluating: configs/vit_trades.yaml
#   ckpt: outputs/checkpoints/vit_trades.pt
#   Clean: 52.07% | FGSM: 27.26% | PGD: 26.29%
#
# Saved: outputs/results_csv/results.csv
# Saved: outputs/plots/robustness_bar.png
# Saved: outputs/plots/pgd_only.png

# %%
ls outputs/plots

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# rm -f outputs/checkpoints/resnet18_pgd_at.pt

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# ls -lt outputs/checkpoints | head
# Out:
# total 1136997
# -rw------- 1 root root  44807831 Dec 17 23:26 resnet18_pgd_at.pt
# -rw------- 1 root root 343286379 Dec 17 19:59 vit_trades.pt
# -rw------- 1 root root  44807831 Dec 17 15:11 resnet18_trades.pt
# -rw------- 1 root root 343286379 Dec 17 15:06 vit_pgd_at.pt
# -rw------- 1 root root 343286219 Dec 17 10:42 vit_clean.pt
# -rw------- 1 root root  44807701 Dec 17 08:51 resnet18_clean.pt

# %%
# !cd /content/drive/MyDrive/adv-robustness-resnet-vit && PYTHONPATH=. python scripts/train.py --config configs/resnet_pgd_at.yaml
# Out:
# Using device: cuda
# Config: {'mode': 'pgd_at', 'model': 'resnet18', 'image_size': 32, 'batch_size': 128, 'epochs': 20, 'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0.0005, 'optimizer': 'sgd', 'eps': 0.01568627, 'alpha': 0.00392157, 'pgd_steps': 10, 'ckpt_path': 'outputs/checkpoints/resnet18_pgd_at.pt'}
# Running PGD Adversarial Training (PGD-AT)
# [PGD-AT] Epoch 01/20 | Test Clean: 0.3268 | Test PGD: 0.2621 | LR: 0.099384
#   ✓ Saved robust checkpoint: outputs/checkpoints/resnet18_pgd_at.pt
# [PGD-AT] Epoch 02/20 | Test Clean: 0.3837 | Test PGD: 0.3009 | LR: 0.097553
#   ✓ Saved robust checkpoint: outputs/checkpoints/resnet18_pgd_at.pt
# [PGD-AT] Epoch 03/20 | Test Clean: 0.4272 | Test PGD: 0.3444 | LR: 0.094550
#   ✓ Saved robust checkpoint: outputs/checkpoints/resnet18_pgd_at.pt
# [PGD-AT] Epoch 04/20 | Test Clean: 0.4516 | Test PGD: 0.3443 | LR: 0.090451
# [PGD-AT] Epoch 05/20 | Test Clean: 0.4863 | Test PGD: 0.3606 | LR: 0.085355
# ...

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# ls -lh --time-style=long-iso outputs/checkpoints/resnet18_pgd_at.pt
# Out:
# -rw------- 1 root root 43M 2025-12-17 23:46 outputs/checkpoints/resnet18_pgd_at.pt

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# rm -f outputs/plots/*.png
# rm -f outputs/results_csv/results.csv

# %%
# !ps -ef | grep eval_and_plot | grep -v grep
# Out:
# root       15348       1 99 Dec17 ?        00:15:46 python3 scripts/eval_and_plot.py --configs configs/resnet_clean.yaml configs/resnet_pgd_at.yaml configs/resnet_trades.yaml configs/vit_clean.yaml configs/vit_pgd_at.yaml configs/vit_trades.yaml

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# PYTHONUNBUFFERED=1 PYTHONPATH=. python -u scripts/eval_and_plot.py \
#   --configs \
#     configs/resnet_clean.yaml \
#     configs/resnet_pgd_at.yaml \
#     configs/resnet_trades.yaml \
#     configs/vit_clean.yaml \
#     configs/vit_pgd_at.yaml \
#     configs/vit_trades.yaml
# Out:
# Process is terminated.

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# ls -lh outputs/plots
# ls -lh outputs/results_csv
# Out:
# total 0
# total 0

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# PYTHONUNBUFFERED=1 PYTHONPATH=. python -u scripts/eval_and_plot.py \
#   --configs \
#     configs/resnet_clean.yaml \
#     configs/resnet_pgd_at.yaml \
#     configs/resnet_trades.yaml \
#     configs/vit_clean.yaml \
#     configs/vit_pgd_at.yaml \
#     configs/vit_trades.yaml
# Out:
# Process is terminated.

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# PYTHONUNBUFFERED=1 PYTHONPATH=. python -u scripts/eval_and_plot.py \
#   --configs \
#     configs/resnet_clean.yaml \
#     configs/resnet_pgd_at.yaml
# Out:
# Using device: cuda
#
# Evaluating: configs/resnet_clean.yaml
#   ckpt: outputs/checkpoints/resnet18_clean.pt
#   Clean: 84.24% | FGSM: 6.32% | PGD: 0.20%
#
# Evaluating: configs/resnet_pgd_at.yaml
#   ckpt: outputs/checkpoints/resnet18_pgd_at.pt
#   Clean: 63.47% | FGSM: 46.38% | PGD: 45.36%
#
# Saved: outputs/results_csv/results.csv
# Saved: outputs/plots/robustness_bar.png
# Saved: outputs/plots/pgd_only.png

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
# ls -lh outputs/plots
# ls -lh outputs/results_csv
# Out:
# total 45K
# -rw------- 1 root root 22K Dec 18 00:22 pgd_only.png
# -rw------- 1 root root 23K Dec 18 00:22 robustness_bar.png
# total 512
# -rw------- 1 root root 154 Dec 18 00:22 results.csv

# %%
# %%bash
# cd /content/drive/MyDrive/adv-robustness-resnet-vit
#
# PYTHONUNBUFFERED=1 PYTHONPATH=. python -u scripts/eval_and_plot.py \
#   --configs \
#     configs/resnet_clean.yaml \
#     configs/resnet_pgd_at.yaml \
#     configs/resnet_trades.yaml \
#     configs/vit_clean.yaml \
#     configs/vit_pgd_at.yaml \
#     configs/vit_trades.yaml
# Out:
# Using device: cuda
#
# Evaluating: configs/resnet_clean.yaml
#   ckpt: outputs/checkpoints/resnet18_clean.pt
#   Clean: 84.24% | FGSM: 6.32% | PGD: 0.17%
#
# Evaluating: configs/resnet_pgd_at.yaml
#   ckpt: outputs/checkpoints/resnet18_pgd_at.pt
#   Clean: 63.47% | FGSM: 46.38% | PGD: 45.34%
#
# Evaluating: configs/resnet_trades.yaml
#   ckpt: outputs/checkpoints/resnet18_trades.pt
#   Clean: 40.89% | FGSM: 24.22% | PGD: 23.69%
#
# Evaluating: configs/vit_clean.yaml
#   ckpt: outputs/checkpoints/vit_clean.pt
#   Clean: 86.19% | FGSM: 1.44% | PGD: 0.00%
#
# Evaluating: configs/vit_pgd_at.yaml
#   ckpt: outputs/checkpoints/vit_pgd_at.pt
#   Clean: 44.36% | FGSM: 31.08% | PGD: 30.87%
#
# Evaluating: configs/vit_trades.yaml
#   ckpt: outputs/checkpoints/vit_trades.pt
#   Clean: 52.07% | FGSM: 27.26% | PGD: 26.32%
#
# Saved: outputs/results_csv/results.csv
# Saved: outputs/plots/robustness_bar.png
# Saved: outputs/plots/pgd_only.png
